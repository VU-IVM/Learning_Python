# %% [markdown]
# Original notebook by Sem Vijverberg for the series 'Python skills for research in Hydrology' for the master Hydrology at the Vrije Universiteit Amsterdam (2019).

# %% [markdown]
# # Functions and Classes

# %% [markdown]
# ## Functions
# Functions are essenstial for writing clear and reproducable code. It allows you to re-use a part of code.

# %%
# let's define a simple function
def x_squared(x):
    y = x**2
    return y

# %%
# let's plug in a value for x
x = 2
y = x_squared(x)
print(y)
# or
print(x_squared(2))
# Out:
# 4
# 4

# %% [markdown]
# Within functions you are dealing with _local_ variables, while outside of functions you are dealing with _global_ variables.

# %%
# A global variable can be accesed from your memory everywhere outside a function
# x was defined earlier and is in my memory
print(x)
# Out:
# 2

# %% [markdown]
# _local_ variables are only defined within a function. For example, let's see what happens if I define the variable _z_ inside the original function.

# %%
def x_squared(x):
    y = x**2
    z = 2*y
    return y

# let's run the function:
y = x_squared(2)
print(y)
# if I now ask for the value of z, it will give a NameError. NameErrors are given when a variable is not defined. 
print(z)
# Out:
# 4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-fad898af6f19> in <module>()
#       8 print(y)
#       9 # if I now ask for the value of z, it will give a NameError. NameErrors are given when a variable is not defined.
# ---> 10 print(z)
#
# NameError: name 'z' is not defined

# %% [markdown]
# Since we didn't return z from the function, it stays within the function as a _local_ variable. So let's also return z:

# %%
def x_squared(x):
    y = x**2
    z = 2*y
    return y, z

# let's run the function:
y, z = x_squared(2)
print(y)
print(z)
# Out:
# 4
# 8

# %% [markdown]
# ## positional versus optional arguments
# Also called non-default vs. default arguments

# %% [markdown]
# Optional arguments can be defined when you 'define' the function, see example below. If you don't specify _i_, it will use the default value 3. This is efficient because it allows to write flexible functions which work 90% of the time, because 90% of the time you need the default setting. But when you ever need to be a bit flexible, you can adapt.

# %%
def x_squared(x, i=3):
    y = x**2
    z = 2*i
    return y, z
# let's run the function:
y, z = x_squared(2)
print(y)
print(z)
# Out:
# 4
# 6

# %% [markdown]
# Arguments without a default value are often called positional arguments, since the order (position) of the argument determines the value the arguments will get.

# %%
def x_squared(x, i):
    y = x**2
    z = 2*i
    return y, z
# let's run the function:
print(x_squared(2, 3))
print(x_squared(3, 2))
# Out:
# (4, 6)
# (9, 4)

# %% [markdown]
# ## kwargs and args
#
# kwargs are keyword arguments, args are simply arguments in a list.
#
# kwargs are basically dictionaries with variables as keys and their concomitant values. To use a normal dictionary as kwrgs, use the **kwrgs: For example:

# %%
kwrgs = {'x' : 2,
         'i' : 4}
def x_squared(x, i=3):
    y = x**2
    z = 2*i
    return y, z
# let's run the function:
y, z = x_squared(**kwrgs)
print(y)
print(z)
# Out:
# 4
# 8

# %% [markdown]
# args are given in list form (in order of function variables), for args you need to add one * instead of two **:

# %%
args = [2, 4]
def x_squared(x, i=3):
    y = x**2
    z = 2*i
    return y, z
# let's run the function:
y, z = x_squared(*args)
print(y)
print(z)
# Out:
# 4
# 8

# %% [markdown]
# If you don't have any default value, you can make you function more clear by stating a certain data type input. For example, perhaps you want the above function to only except floats (will also except integers).

# %%
args = [2., 4]
def x_squared(x=float, i=float):
    y = x**2
    z = 2*i
    return y, z
# let's run the function:
y, z = x_squared(*args)
print(y)
print(z)
# Out:
# 4.0
# 8

# %%
# Indeed, if you now supply a list of values to x..

kwrgs = {'x' : [0,1,2],
         'i' : 4}
def x_squared(x=float, i=float):
    y = x**2
    z = 2*i
    return y, z
# let's run the function:
y, z = x_squared(**kwrgs)
print(y)
print(z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-a079507b8a56> in <module>
#       8     return y, z
#       9 # let's run the function:
# ---> 10 y, z = x_squared(**kwrgs)
#      11 print(y)
#      12 print(z)
#
# <ipython-input-58-a079507b8a56> in x_squared(x, i)
#       4          'i' : 4}
#       5 def x_squared(x=float, i=float):
# ----> 6     y = x**2
#       7     z = 2*i
#       8     return y, z
#
# TypeError: unsupported operand type(s) for ** or pow(): 'list' and 'int'
